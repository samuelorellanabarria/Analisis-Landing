# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelorellanabarria/Analisis-Landing/blob/main/01%20-%20landig_page.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/DataScience/YouTube_AnalisisDeDatos/Landing_Page/Landing 2do Semestre 2022.xlsx")

# %%
df.head()
# Out:
#       Base      tipo_avaluo  valor_propiedad valor_propiedad_valor  \
# 0  Credito    Avalúo Fiscal        200000000                  peso
# 1  Credito    Avalúo Fiscal         60000000                  peso
# 2  Credito    Avalúo Fiscal         20971000                  peso
# 3  Credito    Avalúo Fiscal         30000000                  peso
# 4  Credito  Valor Comercial         33000000                  peso
#
#    monto_credito_socilitar valor_monto_credito_socilitar tipo_de_propiedad  \
# 0                150000000                          peso              Casa
# 1                 12000000                          peso               NaN
# 2                  2000000                          peso              Casa
# 3                 10000000                          peso              Casa
# 4                 20000000                          peso              Casa
#
#             region_propiedad comuna_propiedad                Fecha
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1888 entries, 0 to 1887
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Base                           1888 non-null   object
#  1   tipo_avaluo                    1888 non-null   object
#  2   valor_propiedad                1888 non-null   int64
#  3   valor_propiedad_valor          1888 non-null   object
#  4   monto_credito_socilitar        1888 non-null   int64
#  5   valor_monto_credito_socilitar  1651 non-null   object
#  6   tipo_de_propiedad              1465 non-null   object
#  7   region_propiedad               1465 non-null   object
#  8   comuna_propiedad               1465 non-null   object
#  9   Fecha                          1888 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 147.6+ KB

# %%
df.describe()
# Out:
#        valor_propiedad  monto_credito_socilitar
# count     1.888000e+03             1.888000e+03
# mean      6.505372e+08             1.246787e+08
# std       1.017154e+10             2.615464e+09
# min       0.000000e+00             0.000000e+00
# 25%       1.200000e+07             4.000000e+06
# 50%       3.508002e+07             1.500000e+07
# 75%       7.787500e+07             4.000000e+07
# max       3.000000e+11             8.000000e+10

# %%
df.shape
# Out:
# (1888, 10)

# %%
df.sort_values("valor_propiedad", ascending=False).head()
# Out:
#          Base      tipo_avaluo  valor_propiedad valor_propiedad_valor  \
# 137   Credito    Avalúo Fiscal     300000000000                  peso
# 799   Credito  Valor Comercial     185000000000                  peso
# 1141  Credito    Avalúo Fiscal     150000000000                  peso
# 1140  Credito    Avalúo Fiscal     150000000000                  peso
# 121   Credito  Valor Comercial     123000000000                  peso
#
#       monto_credito_socilitar valor_monto_credito_socilitar tipo_de_propiedad  \
# 137                  11000000                          peso               NaN
# 799                  25000000                          peso               Agr
# 1141              80000000000                          peso               Agr
# 1140              80000000000                          peso               Agr
# 121                  45000000                          peso              Casa
#
#                region_propiedad comuna_propiedad                Fecha
# ...

# %%
df.sort_values("valor_propiedad", ascending=True).head()
# Out:
#          Base tipo_avaluo  valor_propiedad valor_propiedad_valor  \
# 1274  Credito           0                0                  peso
# 518   Credito           0                0                  peso
# 134   Credito           0                0                  peso
# 1109  Credito           0                0                  peso
# 852   Credito           0                0                  peso
#
#       monto_credito_socilitar valor_monto_credito_socilitar tipo_de_propiedad  \
# 1274                 20000000                          peso           Terreno
# 518                      1300                            uf              Casa
# 134                  30000000                          peso              Casa
# 1109                        0                           NaN               NaN
# 852                    800000                          peso               NaN
#
#                region_propiedad comuna_propiedad                Fecha
# ...

# %%
df.sort_values("monto_credito_socilitar", ascending=False).head()
# Out:
#          Base      tipo_avaluo  valor_propiedad valor_propiedad_valor  \
# 1141  Credito    Avalúo Fiscal     150000000000                  peso
# 1140  Credito    Avalúo Fiscal     150000000000                  peso
# 136   Credito    Avalúo Fiscal      35000000000                  peso
# 135   Credito    Avalúo Fiscal      30000000000                  peso
# 1860  Empresa  Valor Comercial      14000000000                  peso
#
#       monto_credito_socilitar valor_monto_credito_socilitar tipo_de_propiedad  \
# 1141              80000000000                          peso               Agr
# 1140              80000000000                          peso               Agr
# 136               10000000000                          peso           Terreno
# 135                5000000000                          peso              Casa
# 1860               2000000000                          peso               NaN
#
#                region_propiedad comuna_propiedad                Fecha
# ...

# %%
df.sort_values("monto_credito_socilitar", ascending=True).head()
# Out:
#          Base      tipo_avaluo  valor_propiedad valor_propiedad_valor  \
# 558   Credito  Valor Comercial             1850                    uf
# 1316  remates    Avalúo Fiscal         60000000                  peso
# 1322  Credito  Valor Comercial         35000000                  peso
# 1323  Credito  Valor Comercial         35000000                  peso
# 1324  Credito  Valor Comercial         40000000                  peso
#
#       monto_credito_socilitar valor_monto_credito_socilitar tipo_de_propiedad  \
# 558                         0                           NaN               NaN
# 1316                        0                           NaN               NaN
# 1322                        0                           NaN               NaN
# 1323                        0                           NaN               NaN
# 1324                        0                           NaN               NaN
#
#      region_propiedad comuna_propiedad                Fecha
# ...

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap = "Blues")
# Out:
# <Axes: >

# %%
correlations = df.corr()
f, ax = plt.subplots()
sns.heatmap(correlations, annot=True)
# Out:
# <ipython-input-47-3dd3a063e7e7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = df.corr()
# <Axes: >

# %%
df = df[df["valor_propiedad"] > 0]
df = df[df["valor_propiedad"] < 5000000000]
df = df[df["monto_credito_socilitar"] > 0]
df = df[df["monto_credito_socilitar"] < 5000000000]

# %%
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-f503e9c6cf11> in <cell line: 1>()
# ----> 1 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install fbprophet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# ...
#   Using cached setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
# Failed to build fbprophet
# ERROR: Could not build wheels for fbprophet, which is required to install pyproject.toml-based projects

# %%
# !pip install pystan
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python setup.py install
# Out:
# python3: can't open file '/content/setup.py': [Errno 2] No such file or directory

# %%
# !python -m pip install prophet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
